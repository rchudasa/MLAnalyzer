# %%
import pyarrow.parquet as pq
import pyarrow as pa # pip install pyarrow==0.7.1
import ROOT
import numpy as np
import glob, os
from skimage.measure import block_reduce # pip install scikit-image
from numpy.lib.stride_tricks import as_strided
# Out:
# Welcome to JupyROOT 6.28/00

# %%
def upsample_array(x, b0, b1):

    r, c = x.shape                                    # number of rows/columns
    rs, cs = x.strides                                # row/column strides
    x = as_strided(x, (r, b0, c, b1), (rs, 0, cs, 0)) # view as a larger 4D array

    return x.reshape(r*b0, c*b1)/(b0*b1)              # create new 2D array with same total occupancy 

def resample_EE(imgECAL, factor=2):

    # EE-
    imgEEm = imgECAL[:140-85] # EE- in the first 55 rows
    imgEEm = np.pad(imgEEm, ((1,0),(0,0)), 'constant', constant_values=0) # for even downsampling, zero pad 55 -> 56
    imgEEm_dn = block_reduce(imgEEm, block_size=(factor, factor), func=np.sum) # downsample by summing over [factor, factor] window
    imgEEm_dn_up = upsample_array(imgEEm_dn, factor, factor)/(factor*factor) # upsample will use same values so need to correct scale by factor**2
    imgECAL[:140-85] = imgEEm_dn_up[1:] ## replace the old EE- rows

    # EE+
    imgEEp = imgECAL[140+85:] # EE+ in the last 55 rows
    imgEEp = np.pad(imgEEp, ((0,1),(0,0)), 'constant', constant_values=0) # for even downsampling, zero pad 55 -> 56
    imgEEp_dn = block_reduce(imgEEp, block_size=(factor, factor), func=np.sum) # downsample by summing over [factor, factor] window
    imgEEp_dn_up = upsample_array(imgEEp_dn, factor, factor)/(factor*factor) # upsample will use same values so need to correct scale by factor*factor
    imgECAL[140+85:] = imgEEp_dn_up[:-1] # replace the old EE+ rows

    return imgECAL

def crop_jet(imgECAL, iphi, ieta, jet_shape=125):

    # NOTE: jet_shape here should correspond to the one used in RHAnalyzer
    off = jet_shape//2
    iphi = int(iphi*5 + 2) # 5 EB xtals per HB tower
    ieta = int(ieta*5 + 2) # 5 EB xtals per HB tower

    # Wrap-around on left side
    if iphi < off:
        diff = off-iphi
        img_crop = np.concatenate((imgECAL[:,ieta-off:ieta+off+1,-diff:],
                                   imgECAL[:,ieta-off:ieta+off+1,:iphi+off+1]), axis=-1)
    # Wrap-around on right side
    elif 360-iphi < off:
        diff = off - (360-iphi)
        img_crop = np.concatenate((imgECAL[:,ieta-off:ieta+off+1,iphi-off:],
                                   imgECAL[:,ieta-off:ieta+off+1,:diff+1]), axis=-1)
    # Nominal case
    else:
        img_crop = imgECAL[:,ieta-off:ieta+off+1,iphi-off:iphi+off+1]

    return img_crop

# %%
# !pwd
# Out:
# /eos/home-i02/r/rchudasa/SWAN_projects/e2e/MLAnalyzer/convertRootFiles

# %%
infile = '/eos/home-i02/r/rchudasa/SWAN_projects/e2e/MLAnalyzer/output_100.root'
outdir = '/eos/home-i02/r/rchudasa/SWAN_projects/e2e/MLAnalyzer/'
decay = 'DYToTauTau'

#infile = '/eos/cms/store/group/phys_heavyions/rchudasa/e2e/'
#outdir = '/eos/cms/store/group/phys_heavyions/rchudasa/e2e/RHAnalyzer_Ntuples/DYToTauTau_M-50_13TeV'
#decay = 'DYToTauTau_M-50_13TeV'

idx = 0

# %%
rhTreeStr = infile 
rhTree = ROOT.TChain("fevt/RHTree")
rhTree.Add(rhTreeStr)
nEvts = rhTree.GetEntries()
assert nEvts > 0
print (" >> Input file:",rhTreeStr)
print (" >> nEvts:",nEvts)
outStr = '%s/%s.parquet.%d'%(outdir, decay, idx) 
print (" >> Output file:",outStr)
# Out:
#  >> Input file: /eos/home-i02/r/rchudasa/SWAN_projects/e2e/MLAnalyzer/output_100.root
#  >> nEvts: 1933
#  >> Output file: /eos/home-i02/r/rchudasa/SWAN_projects/e2e/MLAnalyzer//DYToTauTau.parquet.0

# %%
# Event range to process
iEvtStart = 0
#iEvtEnd   = 10
iEvtEnd   = nEvts 
assert iEvtEnd <= nEvts
print (" >> Processing entries: [",iEvtStart,"->",iEvtEnd,")")

nJets = 0
data = {} # Arrays to be written to parquet should be saved to data dict
sw = ROOT.TStopwatch()
sw.Start()
for iEvt in range(iEvtStart,iEvtEnd):
    print("")

    # Initialize event
    rhTree.GetEntry(iEvt)

    if iEvt % 10 == 0:
        print (" .. Processing entry",iEvt)

    ECAL_energy = np.array(rhTree.ECAL_energy).reshape(280,360)
    ECAL_energy = resample_EE(ECAL_energy)
    HBHE_energy = np.array(rhTree.HBHE_energy).reshape(56,72)
    HBHE_energy = upsample_array(HBHE_energy, 5, 5) # (280, 360)
    TracksAtECAL_pt    = np.array(rhTree.ECAL_tracksPt_atECALfixIP).reshape(280,360)
    TracksAtECAL_dZSig = np.array(rhTree.ECAL_tracksDzSig_atECALfixIP).reshape(280,360)
    TracksAtECAL_d0Sig = np.array(rhTree.ECAL_tracksD0Sig_atECALfixIP).reshape(280,360)
    PixAtEcal_1        = np.array(rhTree.BPIX_layer1_ECAL_atPV).reshape(280,360)
    PixAtEcal_2        = np.array(rhTree.BPIX_layer2_ECAL_atPV).reshape(280,360)
    PixAtEcal_3        = np.array(rhTree.BPIX_layer3_ECAL_atPV).reshape(280,360)
    PixAtEcal_4        = np.array(rhTree.BPIX_layer4_ECAL_atPV).reshape(280,360)
    TibAtEcal_1        = np.array(rhTree.TIB_layer1_ECAL_atPV).reshape(280,360)
    TibAtEcal_2        = np.array(rhTree.TIB_layer2_ECAL_atPV).reshape(280,360)
    TobAtEcal_1        = np.array(rhTree.TOB_layer1_ECAL_atPV).reshape(280,360)
    TobAtEcal_2        = np.array(rhTree.TOB_layer2_ECAL_atPV).reshape(280,360)
    #X_CMSII            = np.stack([TracksAtECAL_pt, TracksAtECAL_dZSig, TracksAtECAL_d0Sig, ECAL_energy, HBHE_energy], axis=0) # (5, 280, 360)
    #X_CMSII            = np.stack([TracksAtECAL_pt, TracksAtECAL_dZSig, TracksAtECAL_d0Sig, ECAL_energy, HBHE_energy, PixAtEcal_1, PixAtEcal_2, PixAtEcal_3, PixAtEcal_4, TibAtEcal_1, TibAtEcal_2, TobAtEcal_1, TobAtEcal_2], axis=0) # (13, 280, 360)
    X_CMSII            = np.stack([TracksAtECAL_pt, TracksAtECAL_dZSig, TracksAtECAL_d0Sig, ECAL_energy, 
                                   HBHE_energy, PixAtEcal_1, PixAtEcal_2, PixAtEcal_3, PixAtEcal_4, 
                                   TibAtEcal_1, TibAtEcal_2, TobAtEcal_1, TobAtEcal_2], axis=0) # (13, 280, 360)
    #X_CMSII            = np.stack([TracksAtECAL_pt, ECAL_energy, HBHE_energy, PixAtEcal_1, 
    #                               PixAtEcal_2, PixAtEcal_3, PixAtEcal_4], axis=0) #
    #data['X_CMSII']    = np.stack([TracksAtECAL_pt, ECAL_energy, HBHE_energy, PixAtEcal_1, 
    #                               PixAtEcal_2, PixAtEcal_3, PixAtEcal_4], axis=0) # (7, 280, 360)
    #data['X_CMSII'] = np.stack([TracksAtECAL_pt, ECAL_energy, HBHE_energy], axis=0) # (3, 280, 360)
    #data['X_CMSII'] = np.stack([TracksAtECAL_pt, TracksAtECAL_dz, TracksAtECAL_d0, ECAL_energy], axis=0) # (4, 280, 360)
    #data['X_CMSII'] = np.stack([TracksAtECAL_pt, TracksAtECAL_dz, TracksAtECAL_d0, ECAL_energy, HBHE_energy, PixAtEcal_1, PixAtEcal_2, PixAtEcal_3, PixAtEcal_4], axis=0) # (9, 280, 360)

    # Jet attributes 
    ys      = rhTree.jet_IsTau
    jetMs   = rhTree.jet_M
    jetPts  = rhTree.jet_Pt
    dRs    = rhTree.jet_GendR
    iphis  = rhTree.jetSeed_iphi
    ietas  = rhTree.jetSeed_ieta
    pdgIds = rhTree.gen_pdgId
    
    njets  = len(ys)

    print ("event", iEvt, " no of jets", njets)
    #print("subjet ", type(np.array(rhTree.subJetE)[0]))
    for i in range(njets):

        data['y']       = ys[i]
        '''
        data['jetM']    = jetMs[i]
        data['jetPt']   = jetPts[i]
        data['dR']    = dRs[i]
        data['iphi']  = iphis[i]
        data['ieta']  = ietas[i]
        data['pdgId'] = pdgIds[i]
        data['metSumEt'] = np.float32(rhTree.MET_sumET)[0]
        data['nPVtx']    = rhTree.nVtx
        data['nPVtx_x']  = np.array(rhTree.Vtx_x)[0]
        data['nPVtx_y']  = np.array(rhTree.Vtx_y)[0]
        data['X_jet'] = crop_jet(X_CMSII, data['iphi'], data['ieta']) # (13, 125, 125)
        #data['X_jet'] = X_CMSII # (13, 125, 125)
        '''
        #data['sec_vtx_Pt'] = np.array(1, dtype=float)
        if njets >1 :
            #data['jet_pfcand_E'] = np.array(np.array(rhTree.jetPFCandE)[i], dtype=float)
            #data['sec_vtx_Pt'] =  np.array(np.array(rhTree.jetSV_Pt)[i], dtype=float)
            print("2 Sec vertex pt:", np.array(np.array(rhTree.jetSV_Pt)[i], dtype=float).size ) 
            numSecVtx = np.array(np.array(rhTree.jetSV_Pt)[i], dtype=float).size
            if numSecVtx == 0:
                data['sec_vtx_Pt'] = np.array([0.0])
            else:
                data['sec_vtx_Pt'] =  np.array(np.array(rhTree.jetSV_Pt)[i], dtype=float)
                


        else :
            #data['jet_pfcand_E'] = np.array(rhTree.jetPFCandE, dtype=float)[i]
            numSecVtx = np.array(rhTree.jetSV_Pt, dtype=float)[i].size
            if numSecVtx == 0:
                data['sec_vtx_Pt'] = np.array([0.0])
            else:
                data['sec_vtx_Pt'] = np.array(rhTree.jetSV_Pt, dtype=float)[i]
            #data['sec_vtx_Pt'] =  np.array(rhTree.jetSV_Pt, dtype=float)[i]
            #print("Sec vertex pt:", np.array(rhTree.jetSV_Pt)[i] )
            #print("1 Sec vertex pt: ", data['sec_vtx_Pt'].size, data['sec_vtx_Pt'])   

                  
        
        #print("subjet array size:", np.array(rhTree.subJetE)[i])

        # Create pyarrow.Table
        #for d in data.values():
        #    print(d)

        pqdata = [pa.array([d]) if (np.isscalar(d) or type(d) == list) else pa.array([d.tolist()]) for d in data.values()]

        print(data.values())
        table = pa.Table.from_arrays(pqdata, list(data.keys()))

        if nJets == 0:
            writer = pq.ParquetWriter(outStr, table.schema, compression='snappy')

        writer.write_table(table)

        nJets += 1

        #print("Event:", iEvt, "  jetM:", jetMs[i], " pt:" , jetPts[i], " iPhi:", iphis[i], " iEta:", ietas[i])

writer.close()
print (" >> nJets:",nJets)
print (" >> Real time:",sw.RealTime()/60.,"minutes")
print (" >> CPU time: ",sw.CpuTime() /60.,"minutes")
print ("========================================================")
# Out:
#  >> Processing entries: [ 0 -> 1933 )
#
#  .. Processing entry 0
# event 0  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 1  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 2  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 3  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 4  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 5  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 6  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 7  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 8  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 9  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 10
# event 10  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 11  no of jets 1
# dict_values([1.0, array([5.58279705])])
#
# event 12  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 13  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 14  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 15  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 16  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 17  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 18  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 19  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 20
# event 20  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 21  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 22  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 23  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 24  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 25  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 26  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 27  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([14.98342609])])
# /tmp/ipykernel_630/1803580875.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   print("2 Sec vertex pt:", np.array(np.array(rhTree.jetSV_Pt)[i], dtype=float).size )
# /tmp/ipykernel_630/1803580875.py:84: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   numSecVtx = np.array(np.array(rhTree.jetSV_Pt)[i], dtype=float).size
# /tmp/ipykernel_630/1803580875.py:88: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data['sec_vtx_Pt'] =  np.array(np.array(rhTree.jetSV_Pt)[i], dtype=float)
# event 28  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 29  no of jets 1
# dict_values([1.0, array([18.71267319])])
#
#  .. Processing entry 30
# event 30  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 31  no of jets 1
# dict_values([1.0, array([28.10563278])])
#
# event 32  no of jets 1
# dict_values([1.0, array([14.05618477])])
#
# event 33  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 34  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 35  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 36  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 37  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 38  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([10.12679672])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 39  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 40
# event 40  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 41  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 42  no of jets 2
# 2 Sec vertex pt: 2
# dict_values([1.0, array([13.74698257, 13.62228966])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([24.78179359])])
#
# event 43  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 44  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 45  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 2
# dict_values([1.0, array([15.57801533, 11.68338108])])
#
# event 46  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 47  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([15.52375031])])
#
# event 48  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 49  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 50
# event 50  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 51  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 52  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 53  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 54  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 55  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 56  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 57  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 58  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([13.82815552])])
#
# event 59  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 60
# event 60  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 61  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 62  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([32.57194519])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 63  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 64  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 65  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 66  no of jets 1
# dict_values([1.0, array([14.21347427])])
#
# event 67  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 68  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 69  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 70
# event 70  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 71  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 72  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 73  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 74  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 75  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 76  no of jets 1
# dict_values([1.0, array([13.07059479])])
#
# event 77  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 78  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 79  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 80
# event 80  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 81  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 82  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 83  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([23.20645523])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 84  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 85  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 86  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 87  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 88  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 89  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 90
# event 90  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 91  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 92  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 93  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([19.64232445])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 94  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 95  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 96  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 97  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 98  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 99  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 100
# event 100  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 101  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 102  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 103  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 104  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 105  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 106  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 107  no of jets 1
# dict_values([1.0, array([21.56316948])])
#
# event 108  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 109  no of jets 1
# dict_values([1.0, array([8.92183304])])
#
#  .. Processing entry 110
# event 110  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 111  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 112  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 113  no of jets 1
# dict_values([1.0, array([40.41799927])])
#
# event 114  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 115  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 116  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 117  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([4.76378441])])
#
# event 118  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 119  no of jets 1
# dict_values([1.0, array([24.11049843])])
#
#  .. Processing entry 120
# event 120  no of jets 1
# dict_values([1.0, array([23.45193291])])
#
# event 121  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 122  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 123  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 124  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 125  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 126  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 127  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# event 128  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([8.89455318])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 129  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 130
# event 130  no of jets 1
# dict_values([1.0, array([23.340868])])
#
# event 131  no of jets 1
# dict_values([1.0, array([26.92964935])])
#
# event 132  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 133  no of jets 1
# dict_values([1.0, array([22.44754028])])
#
# event 134  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 135  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([23.71343231])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 136  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 137  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 138  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 139  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 140
# event 140  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 141  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 142  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 143  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 144  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 145  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 146  no of jets 1
# dict_values([1.0, array([8.1145153])])
#
# event 147  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 148  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 149  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 150
# event 150  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 151  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 152  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 153  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 154  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 155  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 156  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([34.98397446])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 157  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([25.5399456])])
#
# event 158  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 159  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 160
# event 160  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 161  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 162  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 163  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 164  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([19.98524094])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 165  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 166  no of jets 1
# dict_values([1.0, array([11.18705845])])
#
# event 167  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 168  no of jets 1
# dict_values([1.0, array([21.76897812])])
#
# event 169  no of jets 1
# dict_values([1.0, array([15.80118847])])
#
#  .. Processing entry 170
# event 170  no of jets 1
# dict_values([1.0, array([22.15451813])])
#
# event 171  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 172  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 173  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 174  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 175  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 176  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 177  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([38.02253723])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 178  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 179  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 180
# event 180  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([11.9359808])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 181  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 182  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 183  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 184  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 185  no of jets 1
# dict_values([1.0, array([23.36249161])])
#
# event 186  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([33.63962173])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 187  no of jets 1
# dict_values([1.0, array([16.02228928])])
#
# event 188  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([22.68774986])])
#
# event 189  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 190
# event 190  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 191  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 192  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 193  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 194  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 195  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 196  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 197  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 198  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 199  no of jets 1
# dict_values([1.0, array([37.86570358])])
#
#  .. Processing entry 200
# event 200  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 201  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 202  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 203  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 204  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 205  no of jets 1
# dict_values([1.0, array([15.86518478])])
#
# event 206  no of jets 1
# dict_values([1.0, array([41.44386292])])
#
# event 207  no of jets 1
# dict_values([1.0, array([7.10367727])])
#
# event 208  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 209  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 210
# event 210  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 211  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 212  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 213  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 214  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 215  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 216  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 217  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 218  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 219  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 220
# event 220  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 221  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 222  no of jets 1
# dict_values([1.0, array([20.89930344])])
#
# event 223  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 224  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 225  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 226  no of jets 1
# dict_values([1.0, array([32.29776382])])
#
# event 227  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([14.46503353])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# event 228  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 229  no of jets 1
# dict_values([1.0, array([34.69665909])])
#
#  .. Processing entry 230
# event 230  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 231  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 232  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 233  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 234  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([43.74230957])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 235  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 236  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 237  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 238  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 239  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 240
# event 240  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 241  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 242  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 243  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([19.30104256])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 244  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 245  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 246  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 247  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 248  no of jets 1
# dict_values([1.0, array([4.68766451])])
#
# event 249  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 250
# event 250  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 251  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 252  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 253  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 254  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([31.97380638])])
#
# event 255  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 256  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 257  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 258  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([24.69674683])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 259  no of jets 1
# dict_values([1.0, array([17.48591805])])
#
#  .. Processing entry 260
# event 260  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 261  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 262  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 263  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([27.27979469])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 264  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 265  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([17.80713272])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 266  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 267  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 268  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([36.69330978])])
#
# event 269  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([36.41418457])])
#
#  .. Processing entry 270
# event 270  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 271  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 272  no of jets 1
# dict_values([1.0, array([24.48415375])])
#
# event 273  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 274  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 275  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([34.75111008])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 276  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 277  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 278  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 279  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 280
# event 280  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 281  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 282  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 283  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 284  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 285  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 286  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 287  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 288  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 289  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 290
# event 290  no of jets 1
# dict_values([1.0, array([18.64873505])])
#
# event 291  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 292  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 293  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 294  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 295  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 296  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 297  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 298  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 299  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 300
# event 300  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 301  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 302  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 303  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 304  no of jets 1
# dict_values([1.0, array([30.23407364])])
#
# event 305  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 306  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 307  no of jets 2
# 2 Sec vertex pt: 2
# dict_values([1.0, array([ 3.70164824, 25.55304146])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([27.377388])])
#
# event 308  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 309  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 310
# event 310  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 311  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 312  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 313  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 314  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([20.03474236])])
#
# event 315  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 316  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 317  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 318  no of jets 1
# dict_values([1.0, array([0.])])
# event 319  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 320
# event 320  no of jets 1
# dict_values([1.0, array([9.68928051])])
#
# event 321  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 322  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 323  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 324  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([2.10164475])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 325  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 326  no of jets 1
# dict_values([1.0, array([10.0464325])])
#
# event 327  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 328  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 329  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 330
# event 330  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 331  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 332  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 333  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 334  no of jets 1
# dict_values([1.0, array([54.42687988])])
#
# event 335  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 336  no of jets 1
# dict_values([1.0, array([2.38667178])])
#
# event 337  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 338  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 339  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 340
# event 340  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 341  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 342  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 343  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 344  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 345  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([1.87145364])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 346  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 347  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 348  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 349  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([28.0974617])])
#
#  .. Processing entry 350
# event 350  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 351  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 352  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 353  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 354  no of jets 1
# dict_values([1.0, array([6.25878143])])
#
# event 355  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 356  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 357  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 358  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 359  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 360
# event 360  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 361  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 362  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 363  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 364  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 365  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 366  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 367  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 368  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 369  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 370
# event 370  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 371  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([19.18852234])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 372  no of jets 1
# dict_values([1.0, array([13.84154701])])
#
# event 373  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 374  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 375  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([17.88794518])])
#
# event 376  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 377  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 378  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 379  no of jets 1
# dict_values([1.0, array([16.56100655])])
#
#  .. Processing entry 380
# event 380  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([14.30286503])])
#
# event 381  no of jets 1
# dict_values([1.0, array([15.51752663])])
#
# event 382  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 383  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([18.80755043])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([24.70418358])])
#
# event 384  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 385  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 386  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 387  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([8.43068886])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 388  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 389  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 390
# event 390  no of jets 1
# dict_values([1.0, array([12.91766262])])
#
# event 391  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 392  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 393  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 394  no of jets 1
# dict_values([1.0, array([19.90768242])])
#
# event 395  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 396  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([13.63257313])])
#
# event 397  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 398  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 399  no of jets 1
# dict_values([1.0, array([10.27598667])])
#
#  .. Processing entry 400
# event 400  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 401  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 402  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 403  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 404  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 405  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 406  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 407  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 408  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 409  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([30.65745735])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 410
# event 410  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 411  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 412  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 413  no of jets 1
# dict_values([1.0, array([20.1788044])])
#
# event 414  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 415  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 416  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 417  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 418  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 419  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 420
# event 420  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 421  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 422  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 423  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 424  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 425  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 426  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 427  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 428  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 429  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 430
# event 430  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 431  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 432  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 433  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 434  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 435  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 436  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 437  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 438  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 439  no of jets 1
# dict_values([1.0, array([9.57011509])])
#
#  .. Processing entry 440
# event 440  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 441  no of jets 1
# dict_values([1.0, array([6.5387311])])
#
# event 442  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 443  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 444  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 445  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 446  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([44.88844681])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 447  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 448  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 449  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 450
# event 450  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 451  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 452  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 453  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 454  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 455  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 456  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 457  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 458  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 459  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 460
# event 460  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 461  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 462  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 463  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 464  no of jets 1
# dict_values([1.0, array([51.77988815])])
#
# event 465  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 466  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 467  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 468  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 469  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 470
# event 470  no of jets 1
# dict_values([1.0, array([8.60594368])])
#
# event 471  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 472  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 473  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 474  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 475  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([10.97472477])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([31.58699226])])
#
# event 476  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 477  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 478  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 479  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 480
# event 480  no of jets 1
# dict_values([1.0, array([15.57317543])])
#
# event 481  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 482  no of jets 1
# dict_values([1.0, array([17.52045059])])
#
# event 483  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 484  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 485  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 486  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 487  no of jets 1
# dict_values([1.0, array([1.89972115])])
#
# event 488  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 489  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 490
# event 490  no of jets 1
# dict_values([1.0, array([10.99262428])])
#
# event 491  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 492  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 493  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 494  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 495  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 496  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 497  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 498  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 499  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 500
# event 500  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 501  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 502  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 503  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 504  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 505  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 506  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([24.19822884])])
#
# event 507  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 508  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 509  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 510
# event 510  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 511  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 512  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 513  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# event 514  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 515  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 516  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 517  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([16.30664825])])
#
# event 518  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 519  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 520
# event 520  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 521  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 522  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 523  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 524  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([17.5654335])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 525  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 526  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 527  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 528  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 529  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 530
# event 530  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([24.76819229])])
#
# event 531  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 532  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 533  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 534  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([20.70492363])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 535  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 536  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 537  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 538  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([24.50318718])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 539  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([34.86151886])])
#
#  .. Processing entry 540
# event 540  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 541  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 542  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([35.93699646])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 543  no of jets 1
# dict_values([1.0, array([5.75107861])])
#
# event 544  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 545  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 546  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 547  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 548  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 549  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 550
# event 550  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 551  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 552  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 553  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 554  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 555  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 556  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 557  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 558  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 559  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 560
# event 560  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 561  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 562  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 563  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([21.41557312])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([37.72008133])])
#
# event 564  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 565  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 566  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 567  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 568  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 569  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 570
# event 570  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 571  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([28.82521629])])
#
# event 572  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 573  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 574  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 575  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 576  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 577  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([23.17822266])])
#
# event 578  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 579  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 580
# event 580  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 581  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 582  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 583  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 584  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 585  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 586  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 587  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 588  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([23.55111885])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 589  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 590
# event 590  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 591  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 592  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 593  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 594  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([19.84995079])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 595  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 596  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 597  no of jets 1
# dict_values([1.0, array([31.51937866])])
#
# event 598  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([22.31454659])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 599  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 600
# event 600  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 601  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 602  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 603  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 604  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([4.78867626])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 605  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# event 606  no of jets 1
# dict_values([1.0, array([26.15656471])])
#
# event 607  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 608  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 609  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 610
# event 610  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 611  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 612  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 613  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 614  no of jets 1
# dict_values([1.0, array([25.89638901])])
#
# event 615  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 616  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 617  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 618  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 619  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 620
# event 620  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 621  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 622  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 623  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([21.54611397])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 624  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 625  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 626  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 627  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 628  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 629  no of jets 1
# dict_values([1.0, array([13.48221684])])
#
#  .. Processing entry 630
# event 630  no of jets 1
# dict_values([1.0, array([38.38819885])])
#
# event 631  no of jets 1
# dict_values([1.0, array([26.11102295])])
#
# event 632  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 633  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 634  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 635  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 636  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 637  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 638  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 639  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 640
# event 640  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 641  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([32.70594406])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 642  no of jets 1
# dict_values([1.0, array([20.68723106])])
#
# event 643  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 644  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 645  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 646  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 1
# dict_values([1.0, array([31.53664398])])
#
# event 647  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 648  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([34.8547821])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 649  no of jets 1
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 650
# event 650  no of jets 1
# dict_values([1.0, array([11.21808529])])
#
# event 651  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 652  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 653  no of jets 1
# dict_values([1.0, array([2.68512869, 3.35839367])])
#
# event 654  no of jets 2
# 2 Sec vertex pt: 1
# dict_values([1.0, array([17.48033142])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
# event 655  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 656  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 657  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 658  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 659  no of jets 2
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
# 2 Sec vertex pt: 0
# dict_values([1.0, array([0.])])
#
#  .. Processing entry 660
# event 660  no of jets 1
# dict_values([1.0, array([0.])])
#
# event 661  no of jets 1
# dict_values([1.0, array([25.37278175])])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_630/1803580875.py in <module>
#      32     TibAtEcal_1        = np.array(rhTree.TIB_layer1_ECAL_atPV).reshape(280,360)
#      33     TibAtEcal_2        = np.array(rhTree.TIB_layer2_ECAL_atPV).reshape(280,360)
# ---> 34     TobAtEcal_1        = np.array(rhTree.TOB_layer1_ECAL_atPV).reshape(280,360)
#      35     TobAtEcal_2        = np.array(rhTree.TOB_layer2_ECAL_atPV).reshape(280,360)
#      36     #X_CMSII            = np.stack([TracksAtECAL_pt, TracksAtECAL_dZSig, TracksAtECAL_d0Sig, ECAL_energy, HBHE_energy], axis=0) # (5, 280, 360)
#
# TypeError: data type '<f0' not understood
# cling JIT session error: Cannot allocate memory
# cling JIT session error: Cannot allocate memory

# %%
data = pqIn.read_row_group(5).to_pydict()

# %%
np.float32(data['X_jet'][0]).shape

# %%
data['nPVtx_x'][0]

# %%
type(data['metSumEt'])

# %%
type(data['metSumEt'][0])

# %%
type(data['metSumEt'][0][0])
